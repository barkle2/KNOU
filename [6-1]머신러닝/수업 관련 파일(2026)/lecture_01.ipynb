# %%
a = 5

# %%
type(a)
# Out:
# int

# %%
b = float(a)

# %%
b
# Out:
# 5.0

# %%
type(b)
# Out:
# float

# %%
c = "Alice"

# %%
type(c)
# Out:
# str

# %%
d = True

# %%
type(d)
# Out:
# bool

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'cherry', 'orange']

# %%
print(fruits[0])
print(fruits[1:3])
print(fruits[-1])
# Out:
# apple
# ['cherry', 'orange']
# orange

# %%
student_info = ("Alice", "20241234", 3)

# %%
student_info[1]
# Out:
# '20241234'

# %%
student_info[1] = "20245678"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 student_info[1] = "20245678"
#
# TypeError: 'tuple' object does not support item assignment

# %%
person = {"name": "Alice", "age": 25, "city": "Seoul"}
person["name"]
# Out:
# 'Alice'

# %%
person.update({"age": 26})
person
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'Seoul'}

# %%
person["job"] = "Developer"
del person["city"]
person
# Out:
# {'name': 'Alice', 'age': 26, 'job': 'Developer'}

# %%
x = 10
y = 20
print(x < y)
# Out:
# True

# %%
age = 25
if age >= 20:
    print("성인입니다.")
elif age >= 13:
    print("청소년입니다.")
else:
    print("어린이입니다.")
# Out:
# 성인입니다.

# %%
is_member = True  # True: 회원, False: 비회원
borrowed_books = 3  # 현재 대출 중인 책 수

# 대출 가능 여부 확인
if is_member:  # 회원일 경우
    if borrowed_books < 5:  # 최대 대출 한도 미만일 경우
        can_borrow = True
        print("대출이 가능합니다.")
    else:  # 최대 대출 한도에 도달한 경우
        can_borrow = False
        print("대출 한도에 도달하여 더 이상 대출할 수 없습니다.")
else:  # 비회원일 경우
    can_borrow = False
    print("비회원은 대출할 수 없습니다. 회원 가입이 필요합니다.")
# Out:
# 대출이 가능합니다.

# %%
temperature = 38.5  # 체온 (°C)
heart_rate = 105    # 심박수 (bpm)
blood_pressure = 150 # 혈압 (수축기 mmHg)

# 건강 상태에 따른 경고 메시지
if temperature > 37.5:
    print("경고: 체온이 높습니다.")
if heart_rate > 100:
    print("경고: 심박수가 높습니다.")
if blood_pressure > 140:
    print("경고: 혈압이 높습니다.")
# Out:
# 경고: 체온이 높습니다.
# 경고: 심박수가 높습니다.
# 경고: 혈압이 높습니다.

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
count = 0
while count < 3:
    print("반복 중입니다.")
    count += 1
# Out:
# 반복 중입니다.
# 반복 중입니다.
# 반복 중입니다.

# %%
count = 0
while True:
    print(count)
    if count >= 3:
        break
    count += 1
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(5):
    if i == 2:
        break
    print(i)
# Out:
# 0
# 1

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
for i in range(2, 10):  # 구구단 2단부터 9단
    for j in range(1, 10):  # 각 단의 곱셈
        print(f"{i} x {j} = {i * j}")
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %%
names = ["Alice", "Bob", "Charlie"]
scores = [85, 90, 78]

# %%
list(zip(names, scores))
# Out:
# [('Alice', 85), ('Bob', 90), ('Charlie', 78)]

# %%
for name, score in zip(names, scores):
    print(f"{name}의 점수는 {score}점입니다.")
# Out:
# Alice의 점수는 85점입니다.
# Bob의 점수는 90점입니다.
# Charlie의 점수는 78점입니다.

# %%
def greet(name="손"):
    print(f"안녕하세요, {name}님!")

# %%
greet()
greet("Alice")
# Out:
# 안녕하세요, 손님!
# 안녕하세요, Alice님!

# %%
def calculate_operations(a, b):
    addition = a + b
    subtraction = a - b
    multiplication = a * b
    division = a / b
    return addition, subtraction, multiplication, division

# %%
calculate_operations(10, 2)
# Out:
# (12, 8, 20, 5.0)
